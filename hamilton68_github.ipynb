# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/.../hamilton68.csv')

# %%
df_retweets = pd.read_csv('/.../hamilton68_retweets.csv')

# %%
#format main data frame

concat_df = pd.concat([df, df_retweets])
concat_df = concat_df[['url', 'date', 'renderedContent', 'user', 'followersCount', 'createdAt', 'Bio',\
                      'replyCount', 'retweetCount', 'likeCount', 'links',\
                      'retweetedTweet', 'quotedTweet', 'inReplyToUser',\
                      'hashtags', 'viewCount', 'media']]
concat_df.rename(columns = {'quotedTweet':'quotedUser', 'retweetedTweet': 'retweetedUser'}, inplace=True)
concat_df['date'] = concat_df['date'].astype('datetime64[ns]')
concat_df.index = concat_df['date']
concat_df['date'] = concat_df.index
concat_df.sort_index(ascending=True, inplace=True)
concat_df.fillna(value='--', inplace=True)
concat_df[['replyCount', 'retweetCount', 'likeCount', 'followersCount', 'viewCount']].fillna(value=0, inplace=True)
concat_df['total_engagements'] = concat_df['replyCount'] + concat_df['retweetCount'] \
+ concat_df['likeCount']
concat_df = concat_df[concat_df['date'].between('2023-01-26', '2023-02-11')]
concat_df = concat_df[concat_df['renderedContent'].str.contains('Hamilton 68', case=False)]

# %%
#determine users most active in the discussion surroung Hamilton 68

from collections import Counter
import re

users_list = []
users_count_list = []
users_counter = Counter()

for i in concat_df['user']:
    users_counter.update(i.split())
    
for i in users_counter:
    users_list.append(i)
    users_count_list.append(users_counter[i])

# %%
#determine most frequently used hashtags in relation to Hamilton 68

hashtag_list = []
hashtag_count_list = []
hashtag_counter = Counter()

for i in range(len(concat_df)):
    if concat_df.iloc[i, :]['hashtags'] != '--': #hashtags
        if concat_df.iloc[i, :]['retweetedUser'] == '--': #retweetedUser
            i_list = re.split("', '", concat_df.iloc[i, :]['hashtags'])
            for tag in i_list:
                tag = re.sub("\[", '', tag)
                tag = re.sub("\]", '', tag)
                tag = re.sub("\[", '', tag)
                tag = re.sub("'", '', tag)
                hashtag_counter.update(tag.split())
    
for i in hashtag_counter:
    hashtag_list.append(i)
    hashtag_count_list.append(hashtag_counter[i])

# %%
#visualize most frequent hashtags

sns.set_style('whitegrid', {"grid.color": ".6", "grid.linestyle": ":", 'axes.edgecolor': 'Black', 
             'axes.grid': True})

f, axes = plt.subplots(figsize=(7,6))

hashtag_top = 15

hashtag_df = pd.DataFrame({'hashtag': hashtag_list,
                          'hashtag_count': hashtag_count_list}).sort_values\
('hashtag_count', ascending=False)[:hashtag_top]

ax = sns.barplot(data=hashtag_df, y='hashtag', x='hashtag_count', color='DarkBlue')

ax.set(ylabel=None)
ax.set_xlabel('\nCount', fontsize=14, fontweight='bold', fontname="Plantagenet Cherokee")
ax.tick_params(axis='y', labelsize=12)

ax.set_title('\nTop ' + str(hashtag_top) + ' Hashtags\n', fontsize=22,\
         fontweight='bold', fontname="Plantagenet Cherokee", color='Red')


sns.despine()
plt.tight_layout()
# plt.show()

# f.savefig('/.../hashtags.jpg', bbox_inches='tight')

# %%
#visualize users most frequently using "Hamilton 68"

f, axes = plt.subplots(figsize=(7,6))

users_top = 20

users_df = pd.DataFrame({'user': users_list,
                          'number_of_posts': users_count_list}).sort_values\
('number_of_posts', ascending=False)[:users_top]

ax = sns.barplot(data=users_df, y='user', x='number_of_posts', color='DarkBlue')

ax.set(ylabel=None)
ax.set_xlabel('\nTweet Count', fontsize=14, fontweight='bold', fontname="Plantagenet Cherokee")
ax.tick_params(axis='y', labelsize=11)

ax.set_title('\nTop ' + str(users_top) + ' Users by Number of Tweets Featuring "Hamilton68"\n', fontsize=22,\
         fontweight='bold', fontname="Plantagenet Cherokee", color='Red')


sns.despine()
plt.tight_layout()
# plt.show()

# f.savefig('/.../top_by_tweets.jpg', bbox_inches='tight')

# %%
# concat_df[concat_df['date'].between('2023-02-01', '2023-02-02')].head(50)

# %%
#determine total engagmeent for each user with tweets containing "Hamilton 68"

user_dict = {'user': [], 'total_engagements': []}

for i in range(len(concat_df)):
    if concat_df.iloc[i, :]['retweetedUser'] == '--':
        if concat_df.iloc[i, :]['user'] not in user_dict['user']:
            user_dict['user'].append(concat_df.iloc[i, :]['user'])
            user_dict['total_engagements'].append(0)
        index = user_dict['user'].index(concat_df.iloc[i, :]['user'])
        user_dict['total_engagements'][index] += concat_df.iloc[i, :]['total_engagements']
    
total_engagements_user_df = pd.DataFrame.from_dict(user_dict).sort_values('total_engagements', ascending=False)

# %%
#determine users most frequently engaged with in tweets featuring "Hamilton 68"

engaged_with_counter1 = Counter()
engaged_with_list1 = []
count_list1 = []

def engaged_with_count(df, counter_, list, count_list):
    counter = 0
    for i in df['quotedUser']:
        if i != '--':
            if df['retweetedUser'][counter] == '--':
                counter_.update(i.split())
        counter += 1

    for i in df['retweetedUser']:
        if i != '--':
            counter_.update(i.split())

    for i in df['inReplyToUser']:
        if i != '--':
            counter_.update(i.split())

    for i in counter_.most_common(len(counter_)):
        if len(i[0]) > 2:
            list.append(i[0])
            count_list.append(i[1])
            
engaged_with_count(concat_df, engaged_with_counter1, engaged_with_list1, count_list1)

# %%
#integrity checks:

# engaged_with_counter1['KanekoaTheGreat']
# edges_list_engagements_df[edges_list_engagements_df['target']=='KanekoaTheGreat'].count()

# %%
#produce nodes and edges tables

source_list = []
host_target_list = []


def sna_list(include_replies):
    for i in range(len(concat_df)):
        if concat_df.iloc[i, :]['retweetedUser'] != '--':
            source_list.append(concat_df.iloc[i, :]['user'])
            host_target_list.append(concat_df.iloc[i, :]['retweetedUser'])
        if concat_df.iloc[i, :]['quotedUser'] != '--':
            if concat_df.iloc[i, :]['retweetedUser'] == '--':
                source_list.append(concat_df.iloc[i, :]['user'])
                host_target_list.append(concat_df.iloc[i, :]['quotedUser'])
        if include_replies=='yes':
            if concat_df.iloc[i, :]['inReplyToUser'] != '--':
                source_list.append(concat_df.iloc[i, :]['user'])
                host_target_list.append(concat_df.iloc[i, :]['inReplyToUser'])
                
sna_list('yes')

id_list = list(set(source_list + host_target_list))

nodes_list_engagements_df = pd.DataFrame({'id': id_list,
                                  'label': id_list})
edges_list_engagements_df = pd.DataFrame({'source': source_list,
                                     'target': host_target_list})

# nodes_list_engagements_df.to_csv('/.../hamliton68_engagements_nodes.csv', sep=',', index=False)
# edges_list_engagements_df.to_csv('/...hamilton68_engagements_edges.csv', sep=',', index=False)

# %%
#visualize users most frequently engaged with in tweets featuring "Hamilton 68"

f, axes = plt.subplots(1,2, figsize=(12,6))

engaged_with_top = 15

engagements_from_df = pd.DataFrame({'user': engaged_with_list1,'number_of_posts': count_list1}).sort_values\
('number_of_posts', ascending=False)[:engaged_with_top]

ax1 = sns.barplot(data=engagements_from_df, y='user', x='number_of_posts', color='DarkBlue', ax=axes[0])

engagement_top = 15

total_engagements_user_df2 = pd.DataFrame.from_dict(user_dict).sort_values\
('total_engagements', ascending=False)[:engagement_top]

ax2 = sns.barplot(data=total_engagements_user_df2, y='user', x='total_engagements', color='DarkBlue', ax=axes[1])


ax1.set(ylabel=None)
ax1.set_xlabel('\nNumber of Users', fontsize=14, fontweight='bold', fontname="Plantagenet Cherokee")
ax1.tick_params(axis='y', labelsize=10)
ax1.set_title('Top ' + str(engaged_with_top) + ' Users by Engagements\n From Tweets Featuring\
 "Hamilton 68"\n', fontsize=16, fontweight='bold', fontname="Plantagenet Cherokee", color='Black')

ax2.set(ylabel=None)
ax2.set_xlabel('\nNumber of Users', fontsize=14, fontweight='bold', fontname="Plantagenet Cherokee")
ax2.tick_params(axis='y', labelsize=12)
ax2.set_title('Top ' + str(engagement_top) + ' Users By Engagement From\n \
Replies, Retweets and Likes\n', fontsize=16, fontweight='bold', fontname="Plantagenet Cherokee", color='Black')

f.suptitle('Top Users By Engagements Received', fontsize=22, fontweight='bold', color='Red', \
          fontname="Plantagenet Cherokee")

sns.despine()
plt.tight_layout()
# plt.show()

# f.savefig('/.../top_by_enagement.jpg', bbox_inches='tight')

# %%
#visualize time series for occurrence of "Hamilton 68"
sns.set_style('whitegrid', {"grid.color": ".8", "grid.linestyle": ":", 'axes.edgecolor': 'Black', 
             'axes.grid': True})

f, axes = plt.subplots(1, 2, figsize=(12,6))

#resample to determine activity over time
resampled_df_daily = concat_df['url'].resample('d').count().to_frame()
resampled_df_daily.rename(columns={'url': 'count'}, inplace=True)
resampled_df_daily['date'] = resampled_df_daily.index
resampled_df_daily = resampled_df_daily[['date', 'count']]

resampled_df_hourly = concat_df['url'].resample('h').count().to_frame()
resampled_df_hourly.rename(columns={'url': 'count'}, inplace=True)
resampled_df_hourly['date'] = resampled_df_hourly.index
resampled_df_hourly = resampled_df_hourly[['date', 'count']]


ax1 = sns.lineplot(data=resampled_df_daily, x=resampled_df_daily['date'], y=resampled_df_daily['count'], color='DarkBlue', ax=axes[0])
ax2 = sns.lineplot(data=resampled_df_hourly, x=resampled_df_hourly['date'], y=resampled_df_hourly['count'], color='DarkBlue', ax=axes[1])

ax1.set(ylabel=None)
ax1.set_xlabel('\nDate', fontsize=14, fontweight='bold', fontname="Plantagenet Cherokee")
ax1.set_ylabel('Count\n', fontsize=14, fontweight='bold', fontname="Plantagenet Cherokee")
ax1.tick_params(axis='y', labelsize=10)
ax1.tick_params(axis='x', rotation=35)
ax1.set_title('Daily Number of Tweets Featuring "Hamilton 68"\n', fontsize=16,\
         fontweight='bold', fontname="Plantagenet Cherokee", color='Black')

ax2.set(ylabel=None)
ax2.set_xlabel('\nDate', fontsize=14, fontweight='bold', fontname="Plantagenet Cherokee")
ax2.set_ylabel('Count\n', fontsize=14, fontweight='bold', fontname="Plantagenet Cherokee")
ax2.tick_params(axis='y', labelsize=10)
ax2.tick_params(axis='x', rotation=35)
ax2.set_title('Hourly Number of Tweets Featuring "Hamilton 68"\n', fontsize=16,\
         fontweight='bold', fontname="Plantagenet Cherokee", color='Black')

import matplotlib.dates as mdates
ax1.xaxis.set_major_locator(mdates.DayLocator(interval=2))
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%b-%d-%Y'))
ax2.xaxis.set_major_locator(mdates.DayLocator(interval=2))
ax2.xaxis.set_major_formatter(mdates.DateFormatter('%b-%d-%Y'))

f.suptitle('Time Series for Number of Tweets Featuring "Hamilton 68"', fontweight='bold',\
          fontname='Plantagenet Cherokee', fontsize=28, color='Red')
sns.despine()
plt.tight_layout()
# plt.show()

# f.savefig('/.../time_series.jpg', bbox_inches='tight')

# %%
#explore tweets during hour with most engagement

# pd.set_option('max_colwidth', 400)
# pd.set_option('display.max_rows', None)
# concat_df[concat_df['date'].between('2023-02-01 14:00:00', '2023-02-01 15:00:00')]
# Out:
#                                                                                 url  \
# date
# 2023-02-01 14:00:06      https://twitter.com/MZHemingway/status/1620784055490080769
# 2023-02-01 14:00:30           https://twitter.com/FDRLST/status/1620784156228698112
# 2023-02-01 14:00:40    https://twitter.com/RamaciSuzanne/status/1620784198259970048
# 2023-02-01 14:01:14       https://twitter.com/guzziboy66/status/1620784343345135617
# 2023-02-01 14:01:21        https://twitter.com/hardwdray/status/1620784372654952448
# 2023-02-01 14:01:28    https://twitter.com/Flyfishinmary/status/1620784400425435136
# 2023-02-01 14:01:31    https://twitter.com/scottmathews0/status/1620784415097102336
# 2023-02-01 14:01:36         https://twitter.com/nixvicon/status/1620784432369250304
# 2023-02-01 14:01:39   https://twitter.com/hanjarasjames2/status/1620784448353734658
# 2023-02-01 14:01:42      https://twitter.com/TLStratford/status/1620784461033136128
# 2023-02-01 14:01:52   https://twitter.com/AndreaKyanniej/status/1620784501189410816
# 2023-02-01 14:02:04  https://twitter.com/carlsbadbugkil1/status/1620784551248416768
# 2023-02-01 14:02:12  https://twitter.com/De_PloribusUnum/status/1620784584689606656
# 2023-02-01 14:02:17         https://twitter.com/ELomalli/status/1620784606290255872
# 2023-02-01 14:02:20   https://twitter.com/TrueJustLovely/status/1620784616843128832
# 2023-02-01 14:02:26           https://twitter.com/Zoom81/status/1620784644353581057
# 2023-02-01 14:02:30          https://twitter.com/nedryun/status/1620784660237221895
# 2023-02-01 14:02:32     https://twitter.com/DogMom4Ever5/status/1620784670639296513
# 2023-02-01 14:02:39  https://twitter.com/LynnWal48173451/status/1620784700313980928
# 2023-02-01 14:02:47     https://twitter.com/statendd2023/status/1620784730718498816
# 2023-02-01 14:02:51        https://twitter.com/DjkLarson/status/1620784748682686464
# 2023-02-01 14:02:52     https://twitter.com/LadyJane2025/status/1620784751861956608
# 2023-02-01 14:02:52    https://twitter.com/StephenPiment/status/1620784755011907584
# 2023-02-01 14:03:06      https://twitter.com/BlueBoxDave/status/1620784810410262529
# 2023-02-01 14:03:14         https://twitter.com/kbean511/status/1620784845256560641
# 2023-02-01 14:03:17  https://twitter.com/rachel_redeemed/status/1620784859148079105
# 2023-02-01 14:03:24     https://twitter.com/nanalambchop/status/1620784887203762176
# 2023-02-01 14:03:26     https://twitter.com/BoredGrandma/status/1620784895722389505
# 2023-02-01 14:03:31    https://twitter.com/donnakaye2014/status/1620784917243392000
# 2023-02-01 14:03:32  https://twitter.com/1776Liberty4USA/status/1620784919688646656
# 2023-02-01 14:03:32     https://twitter.com/WelbornBeege/status/1620784921483821056
# 2023-02-01 14:03:37   https://twitter.com/BuchenPatricia/status/1620784942409203712
# 2023-02-01 14:03:39  https://twitter.com/TheVelvetMurder/status/1620784948415451136
# 2023-02-01 14:03:39        https://twitter.com/loverooty/status/1620784949367549954
# 2023-02-01 14:03:43  https://twitter.com/De_PloribusUnum/status/1620784965469491200
# 2023-02-01 14:03:43        https://twitter.com/jteismann/status/1620784965712773120
# 2023-02-01 14:03:50      https://twitter.com/xbonesrider/status/1620784998080208896
# 2023-02-01 14:03:59    https://twitter.com/shawn61675445/status/1620785035514368000
# 2023-02-01 14:04:13      https://twitter.com/YEMUSKTRUMP/status/1620785094771494912
# 2023-02-01 14:04:15  https://twitter.com/BernieMalabanan/status/1620785102484799488
# 2023-02-01 14:04:25       https://twitter.com/4Irish1989/status/1620785142477328386
# 2023-02-01 14:04:30         https://twitter.com/PegSta54/status/1620785162526294018
# 2023-02-01 14:04:30     https://twitter.com/PNowhiteflag/status/1620785165021888514
# 2023-02-01 14:04:50        https://twitter.com/c_inabnit/status/1620785246810812416
# 2023-02-01 14:04:54   https://twitter.com/Kathleenb1957B/status/1620785263529320449
# 2023-02-01 14:04:58   https://twitter.com/samadstevens99/status/1620785283120902144
# 2023-02-01 14:05:00   https://twitter.com/a1merryweather/status/1620785291773751296
# 2023-02-01 14:05:05     https://twitter.com/DancingMoonZ/status/1620785312338423809
# 2023-02-01 14:05:21     https://twitter.com/GabberOnMeWe/status/1620785378126090240
# 2023-02-01 14:05:26       https://twitter.com/lord_vinyl/status/1620785398036447232
# 2023-02-01 14:05:37        https://twitter.com/KniteOwls/status/1620785444190580738
# 2023-02-01 14:05:58      https://twitter.com/krbaylor618/status/1620785533461880843
# 2023-02-01 14:06:10        https://twitter.com/ElBarco19/status/1620785584691384321
# 2023-02-01 14:06:14      https://twitter.com/Bandarrados/status/1620785602185793537
# 2023-02-01 14:06:15      https://twitter.com/Lou05316597/status/1620785603339239424
# 2023-02-01 14:06:18   https://twitter.com/RealAlanXavier/status/1620785618237394946
# 2023-02-01 14:06:19       https://twitter.com/billiejomo/status/1620785620909191168
# 2023-02-01 14:06:34       https://twitter.com/JBloom2022/status/1620785683651784706
# 2023-02-01 14:06:37        https://twitter.com/MoviesDoe/status/1620785694703775744
# 2023-02-01 14:06:37       https://twitter.com/Yujinesque/status/1620785695878176769
# 2023-02-01 14:06:39      https://twitter.com/Bandarrados/status/1620785704635891723
# 2023-02-01 14:06:42  https://twitter.com/BrianAlanJordan/status/1620785716908408832
# 2023-02-01 14:06:50        https://twitter.com/C20992803/status/1620785750622208001
# 2023-02-01 14:06:56  https://twitter.com/wanderingswayne/status/1620785777159593984
# 2023-02-01 14:07:06       https://twitter.com/debsinger2/status/1620785817538162688
# 2023-02-01 14:07:23        https://twitter.com/ChrizDDv3/status/1620785888098918400
# 2023-02-01 14:07:25     https://twitter.com/xlr8ing19002/status/1620785896827260928
# 2023-02-01 14:07:35    https://twitter.com/TravlynoGirlo/status/1620785939181355008
# 2023-02-01 14:07:52       https://twitter.com/kranmars33/status/1620786010958491648
# 2023-02-01 14:08:03   https://twitter.com/BuchenPatricia/status/1620786056525414400
# 2023-02-01 14:08:06      https://twitter.com/trykeepup89/status/1620786069510983680
# 2023-02-01 14:08:46  https://twitter.com/CharlesH4698921/status/1620786237887086592
# 2023-02-01 14:08:46    https://twitter.com/KamikazeBonzi/status/1620786239048929280
# 2023-02-01 14:09:08     https://twitter.com/GodHelpUsTX1/status/1620786331680141313
# 2023-02-01 14:09:13    https://twitter.com/CriminologyMr/status/1620786349359112192
# 2023-02-01 14:09:14  https://twitter.com/1ThingIsNeedful/status/1620786353318539266
# 2023-02-01 14:09:18        https://twitter.com/jellen805/status/1620786370896891904
# 2023-02-01 14:09:41      https://twitter.com/andrzej7346/status/1620786468934553600
# 2023-02-01 14:09:41  https://twitter.com/joannes11264600/status/1620786470004101120
# 2023-02-01 14:09:42  https://twitter.com/Melissa34850774/status/1620786473888002049
# 2023-02-01 14:09:48        https://twitter.com/jellen805/status/1620786497434832896
# 2023-02-01 14:10:08        https://twitter.com/Dkonczal1/status/1620786581757112320
# 2023-02-01 14:10:18      https://twitter.com/CnsrvtvKiki/status/1620786622970343425
# 2023-02-01 14:10:33        https://twitter.com/amicusceo/status/1620786687541665794
# 2023-02-01 14:10:37     https://twitter.com/osmo35195362/status/1620786703329034240
# 2023-02-01 14:10:48       https://twitter.com/ryan102857/status/1620786749470556160
# 2023-02-01 14:10:50      https://twitter.com/IsabelB1025/status/1620786757506854913
# 2023-02-01 14:10:56        https://twitter.com/iam_ozzzy/status/1620786784224559104
# 2023-02-01 14:10:57  https://twitter.com/SoniaBe19160025/status/1620786788976689152
# 2023-02-01 14:10:57  https://twitter.com/dougmey11430692/status/1620786787026370561
# 2023-02-01 14:11:02     https://twitter.com/Chris19D1981/status/1620786807729422339
# 2023-02-01 14:11:15  https://twitter.com/WiseConservativ/status/1620786864088305665
# 2023-02-01 14:11:22         https://twitter.com/pk200430/status/1620786890072023041
# 2023-02-01 14:11:23      https://twitter.com/DWDrummer13/status/1620786895969222657
# 2023-02-01 14:11:28      https://twitter.com/DWDrummer13/status/1620786918308085763
# 2023-02-01 14:11:34         https://twitter.com/pk200430/status/1620786943532613632
# 2023-02-01 14:12:06        https://twitter.com/momof5_em/status/1620787077892964352
# 2023-02-01 14:12:46         https://twitter.com/jenlgear/status/1620787245694455809
# 2023-02-01 14:13:12              https://twitter.com/3QD/status/1620787354431520781
# 2023-02-01 14:13:15  https://twitter.com/thelucky7smokes/status/1620787364321951744
# 2023-02-01 14:13:54      https://twitter.com/rollypoly31/status/1620787527958528002
# 2023-02-01 14:13:58      https://twitter.com/rollypoly31/status/1620787544861577216
# 2023-02-01 14:14:07       https://twitter.com/pipers1989/status/1620787582878756864
# 2023-02-01 14:14:24     https://twitter.com/RealBillMack/status/1620787654655873024
# 2023-02-01 14:14:24  https://twitter.com/AndrewM58840394/status/1620787656291651591
# 2023-02-01 14:14:27  https://twitter.com/JohnFromCranber/status/1620787670149636096
# 2023-02-01 14:14:31  https://twitter.com/BlitzseaFishing/status/1620787685903437826
# 2023-02-01 14:14:31    https://twitter.com/MorgandoLeona/status/1620787685496610816
# 2023-02-01 14:14:32            https://twitter.com/vgw4u/status/1620787687002361857
# 2023-02-01 14:14:42         https://twitter.com/ElleZee6/status/1620787732321828864
# 2023-02-01 14:14:43      https://twitter.com/GoVols37872/status/1620787735303958529
# 2023-02-01 14:14:48       https://twitter.com/GirkeHanjo/status/1620787756812345344
# 2023-02-01 14:14:48   https://twitter.com/Mendyspitzer11/status/1620787756262907904
# 2023-02-01 14:14:56   https://twitter.com/Mendyspitzer11/status/1620787788802306048
# 2023-02-01 14:15:00      https://twitter.com/Ken89740599/status/1620787805277528064
# 2023-02-01 14:15:06       https://twitter.com/rdharris55/status/1620787832922206209
# 2023-02-01 14:15:10        https://twitter.com/LynnePeer/status/1620787849133178880
# 2023-02-01 14:15:19  https://twitter.com/deplorableYTubr/status/1620787884398903296
# 2023-02-01 14:15:19   https://twitter.com/Mendyspitzer11/status/1620787886819004416
# 2023-02-01 14:16:16     https://twitter.com/marypatriott/status/1620788124250161152
# 2023-02-01 14:17:15   https://twitter.com/Mendyspitzer11/status/1620788370816520192
# 2023-02-01 14:17:16    https://twitter.com/BrianGoodlife/status/1620788377326080001
# 2023-02-01 14:17:17   https://twitter.com/Mendyspitzer11/status/1620788383042920450
# 2023-02-01 14:17:22      https://twitter.com/BillDeuster/status/1620788402747748353
# 2023-02-01 14:17:24         https://twitter.com/rayes_mc/status/1620788411899719681
# 2023-02-01 14:17:29         https://twitter.com/sodagrrl/status/1620788430019117058
# 2023-02-01 14:17:32    https://twitter.com/quarkdetector/status/1620788443193430016
# 2023-02-01 14:17:44       https://twitter.com/cathydavis/status/1620788494019989505
# 2023-02-01 14:17:50    https://twitter.com/DeniseArmour6/status/1620788518485385216
# 2023-02-01 14:18:03  https://twitter.com/MaryAnn64979589/status/1620788572604485632
# 2023-02-01 14:18:08   https://twitter.com/Mendyspitzer11/status/1620788595073376256
# 2023-02-01 14:18:13      https://twitter.com/pqvenezuela/status/1620788615210213377
# 2023-02-01 14:18:36       https://twitter.com/LigotRamon/status/1620788713541472256
# 2023-02-01 14:18:43    https://twitter.com/JadeStarRoss4/status/1620788742423445507
# 2023-02-01 14:19:00   https://twitter.com/Mendyspitzer11/status/1620788814229946368
# 2023-02-01 14:19:18  https://twitter.com/Cindyta16016742/status/1620788887114379265
# 2023-02-01 14:19:55        https://twitter.com/RicVaDude/status/1620789041842245634
# 2023-02-01 14:20:07     https://twitter.com/LINDAHARRY11/status/1620789094803734528
# 2023-02-01 14:20:12     https://twitter.com/SteveGoebel8/status/1620789113816506368
# 2023-02-01 14:20:27       https://twitter.com/kmcgallion/status/1620789178735931392
# 2023-02-01 14:20:31     https://twitter.com/cptcookswife/status/1620789194040946688
# 2023-02-01 14:21:01     https://twitter.com/Colin_BCBFTD/status/1620789322416033792
# 2023-02-01 14:21:05       https://twitter.com/LigotRamon/status/1620789335762276352
# 2023-02-01 14:21:18       https://twitter.com/LDiamond39/status/1620789389856223232
# 2023-02-01 14:21:26  https://twitter.com/BartleyKWalters/status/1620789426627710976
# 2023-02-01 14:21:39   https://twitter.com/Cheddarchez715/status/1620789480440614912
# 2023-02-01 14:21:50   https://twitter.com/HenshallHarold/status/1620789524535312384
# 2023-02-01 14:22:15    https://twitter.com/MagaPhoenix73/status/1620789629023838208
# 2023-02-01 14:22:25        https://twitter.com/tgingher3/status/1620789670933315584
# 2023-02-01 14:22:32     https://twitter.com/coble_dr_tim/status/1620789703795707904
# 2023-02-01 14:22:37   https://twitter.com/MickeyFisherOK/status/1620789724406505472
# 2023-02-01 14:22:50    https://twitter.com/nadacommunist/status/1620789779871981569
# 2023-02-01 14:22:50     https://twitter.com/coble_dr_tim/status/1620789776113860608
# 2023-02-01 14:22:59       https://twitter.com/sibeltin11/status/1620789813497692161
# 2023-02-01 14:23:16          https://twitter.com/SeyDhue/status/1620789886356951040
# 2023-02-01 14:23:18  https://twitter.com/steffaniekrelov/status/1620789897035657216
# 2023-02-01 14:23:47    https://twitter.com/GeorgeWChilds/status/1620790018787917825
# 2023-02-01 14:24:06  https://twitter.com/WiseConservativ/status/1620790097775063040
# 2023-02-01 14:24:07     https://twitter.com/frankjrojas1/status/1620790101747064832
# 2023-02-01 14:24:14      https://twitter.com/warmer_daze/status/1620790129291063297
# 2023-02-01 14:24:29   https://twitter.com/AmericanRevSon/status/1620790191714873345
# 2023-02-01 14:24:32       https://twitter.com/bruce_juhl/status/1620790205522534400
# 2023-02-01 14:25:47   https://twitter.com/13missedsteps2/status/1620790521047453696
# 2023-02-01 14:25:50           https://twitter.com/jwla56/status/1620790532053286912
# 2023-02-01 14:25:54        https://twitter.com/mittypost/status/1620790548989906944
# 2023-02-01 14:25:56  https://twitter.com/NunoVilhenaSant/status/1620790556371582978
# 2023-02-01 14:26:03       https://twitter.com/KC21118113/status/1620790589016150016
# 2023-02-01 14:26:09  https://twitter.com/NunoVilhenaSant/status/1620790610922975232
# 2023-02-01 14:26:11   https://twitter.com/BytesAndBits82/status/1620790621702356992
# 2023-02-01 14:26:39  https://twitter.com/jambiktoywood25/status/1620790738106867712
# 2023-02-01 14:27:24      https://twitter.com/TheGetchell/status/1620790925118296064
# 2023-02-01 14:27:59    https://twitter.com/LeadFootMan04/status/1620791073785413632
# 2023-02-01 14:28:19  https://twitter.com/TiberiusGlocke1/status/1620791156400607232
# 2023-02-01 14:28:30     https://twitter.com/LauraSturman/status/1620791202655375361
# 2023-02-01 14:29:10        https://twitter.com/JRTexas12/status/1620791370855383041
# 2023-02-01 14:29:19           https://twitter.com/pmcall/status/1620791408948019200
# 2023-02-01 14:29:20  https://twitter.com/DouglasRenteria/status/1620791414279012352
# 2023-02-01 14:29:26         https://twitter.com/factsppl/status/1620791438777946112
# 2023-02-01 14:29:30  https://twitter.com/AllenJa90708626/status/1620791453541859329
# 2023-02-01 14:30:40  https://twitter.com/DevilDogSpitFur/status/1620791747633876992
# 2023-02-01 14:30:40       https://twitter.com/DonPratt59/status/1620791751006109697
# 2023-02-01 14:31:04          https://twitter.com/Netme62/status/1620791850931220481
# 2023-02-01 14:31:18       https://twitter.com/JohnMuseus/status/1620791909835743234
# 2023-02-01 14:31:23   https://twitter.com/Lizzie18877273/status/1620791928014118913
# 2023-02-01 14:31:24   https://twitter.com/TheyCallMeNans/status/1620791932988588033
# 2023-02-01 14:32:00      https://twitter.com/PKY92941436/status/1620792082616156160
# 2023-02-01 14:32:03       https://twitter.com/dbecker132/status/1620792095916318720
# 2023-02-01 14:32:29       https://twitter.com/Quinine184/status/1620792207027621888
# 2023-02-01 14:32:38      https://twitter.com/cindy_hudon/status/1620792245111914497
# 2023-02-01 14:33:03       https://twitter.com/Quinine184/status/1620792348350513152
# 2023-02-01 14:33:21      https://twitter.com/tekotaro_12/status/1620792425366323200
# 2023-02-01 14:33:28           https://twitter.com/debbz8/status/1620792452960370689
# 2023-02-01 14:33:31      https://twitter.com/shakenalamo/status/1620792467414224896
# 2023-02-01 14:34:17  https://twitter.com/ProfMJCleveland/status/1620792659739811840
# 2023-02-01 14:34:17         https://twitter.com/MelKatz5/status/1620792660742275072
# 2023-02-01 14:34:20    https://twitter.com/GloriaBerard4/status/1620792670691131394
# 2023-02-01 14:34:28          https://twitter.com/davisj1/status/1620792705176539136
# 2023-02-01 14:34:33         https://twitter.com/seanmdav/status/1620792725036744704
# 2023-02-01 14:34:34   https://twitter.com/possum30787430/status/1620792730065698816
# 2023-02-01 14:34:41   https://twitter.com/stevesmithsnoq/status/1620792761548161024
# 2023-02-01 14:34:42   https://twitter.com/Bridge2Freedom/status/1620792764215746560
# 2023-02-01 14:34:43        https://twitter.com/wshaw1127/status/1620792769265692672
# 2023-02-01 14:34:45        https://twitter.com/PlasSusan/status/1620792776500875264
# 2023-02-01 14:34:47       https://twitter.com/Bree000007/status/1620792784855912448
# 2023-02-01 14:34:52    https://twitter.com/SylviaWills14/status/1620792807115075587
# 2023-02-01 14:34:53     https://twitter.com/cptcookswife/status/1620792810139185153
# 2023-02-01 14:34:53       https://twitter.com/c2rawlings/status/1620792812366336000
# 2023-02-01 14:34:55          https://twitter.com/mefbama/status/1620792817709887488
# 2023-02-01 14:35:03     https://twitter.com/MichaelJ5454/status/1620792850492555266
# 2023-02-01 14:35:19     https://twitter.com/MikeOhio1776/status/1620792917970542592
# 2023-02-01 14:35:24      https://twitter.com/GumleyRoger/status/1620792941471236096
# 2023-02-01 14:35:38    https://twitter.com/hillingdon531/status/1620792997552996359
# 2023-02-01 14:35:39      https://twitter.com/gordito0791/status/1620793002871631872
# 2023-02-01 14:36:18       https://twitter.com/lillymckim/status/1620793166042628096
# 2023-02-01 14:36:20        https://twitter.com/BuckRoper/status/1620793177031708673
# 2023-02-01 14:36:26         https://twitter.com/Cyanaras/status/1620793199097974784
# 2023-02-01 14:36:27        https://twitter.com/crickie00/status/1620793204848357376
# 2023-02-01 14:36:28        https://twitter.com/Ringo1256/status/1620793210200260608
# 2023-02-01 14:37:11            https://twitter.com/RickU/status/1620793387850006528
# 2023-02-01 14:37:37       https://twitter.com/BSoolittle/status/1620793500110585856
# 2023-02-01 14:37:40       https://twitter.com/BigBro7000/status/1620793511124819969
# 2023-02-01 14:38:03         https://twitter.com/prsny2fl/status/1620793606889181184
# 2023-02-01 14:38:15        https://twitter.com/bronxilla/status/1620793657648627712
# 2023-02-01 14:38:29          https://twitter.com/scubdog/status/1620793714351415297
# 2023-02-01 14:38:29         https://twitter.com/3catzmom/status/1620793714246586368
# 2023-02-01 14:38:32    https://twitter.com/bando07792797/status/1620793730671468544
# 2023-02-01 14:38:37   https://twitter.com/Val29049039Val/status/1620793751626219520
# 2023-02-01 14:39:00       https://twitter.com/thebadegg3/status/1620793846333603842
# 2023-02-01 14:39:00        https://twitter.com/Tallcan18/status/1620793847361212416
# 2023-02-01 14:39:07         https://twitter.com/virgpitt/status/1620793877220454400
# 2023-02-01 14:39:10        https://twitter.com/flatsgene/status/1620793888259833857
# 2023-02-01 14:39:29   https://twitter.com/Skysoldier1968/status/1620793966596870144
# 2023-02-01 14:39:29      https://twitter.com/socrandall3/status/1620793967423148032
# 2023-02-01 14:39:35            https://twitter.com/LDVBU/status/1620793994488995841
# 2023-02-01 14:39:37       https://twitter.com/layersofbs/status/1620794001023725568
# 2023-02-01 14:39:44       https://twitter.com/Chris_plsp/status/1620794030132203520
# 2023-02-01 14:40:18         https://twitter.com/OlenaZIP/status/1620794172784640000
# 2023-02-01 14:40:25  https://twitter.com/carolyn86452721/status/1620794201922469888
# 2023-02-01 14:40:37     https://twitter.com/OKIEMAGA1962/status/1620794254670041088
# 2023-02-01 14:40:38   https://twitter.com/Serendipiterry/status/1620794256591060992
# 2023-02-01 14:40:40  https://twitter.com/Grammypam64Gill/status/1620794265881436160
# 2023-02-01 14:40:47         https://twitter.com/mamacee7/status/1620794294885052417
# 2023-02-01 14:40:57   https://twitter.com/BakerSonPeekay/status/1620794337771802624
# 2023-02-01 14:41:06       https://twitter.com/BeanFromPA/status/1620794376799801344
# 2023-02-01 14:41:11    https://twitter.com/travioli_jill/status/1620794393824497665
# 2023-02-01 14:41:37      https://twitter.com/WeDidItOnce/status/1620794505900462081
# 2023-02-01 14:41:59          https://twitter.com/TTroy76/status/1620794595364978688
# 2023-02-01 14:42:00  https://twitter.com/jambiktoywood25/status/1620794600230363136
# 2023-02-01 14:42:08  https://twitter.com/jambiktoywood25/status/1620794632828502017
# 2023-02-01 14:42:37     https://twitter.com/Jigsaw_Jules/status/1620794754744352768
# 2023-02-01 14:42:55        https://twitter.com/holly1950/status/1620794832791937024
# 2023-02-01 14:42:55      https://twitter.com/poppycarrot/status/1620794833467228160
# 2023-02-01 14:43:09          https://twitter.com/Lrazzo1/status/1620794889528311808
# 2023-02-01 14:43:29      https://twitter.com/Chaipossum1/status/1620794975922552832
# 2023-02-01 14:43:38       https://twitter.com/TCSCushing/status/1620795013256081410
# 2023-02-01 14:43:47         https://twitter.com/akestep2/status/1620795051759800320
# 2023-02-01 14:43:53         https://twitter.com/aranom12/status/1620795073893126145
# 2023-02-01 14:44:34  https://twitter.com/GoodHumanSearch/status/1620795245385637889
# 2023-02-01 14:44:42        https://twitter.com/bmonty423/status/1620795282769477632
# 2023-02-01 14:45:09    https://twitter.com/ChuckStansell/status/1620795393775923200
# 2023-02-01 14:46:12       https://twitter.com/Stizmaster/status/1620795657161424896
# 2023-02-01 14:46:53     https://twitter.com/Suzanne44208/status/1620795828293242881
# 2023-02-01 14:47:05     https://twitter.com/DouglasDilks/status/1620795880231276545
# 2023-02-01 14:47:14  https://twitter.com/traditionalvibe/status/1620795920072998912
# 2023-02-01 14:47:54     https://twitter.com/LStargazer54/status/1620796087950012416
# 2023-02-01 14:47:58         https://twitter.com/LtotheL2/status/1620796103452151808
# 2023-02-01 14:48:32        https://twitter.com/richft349/status/1620796245924265984
# 2023-02-01 14:48:37           https://twitter.com/RTikia/status/1620796267940167680
# 2023-02-01 14:48:45        https://twitter.com/DeanOrman/status/1620796301867876353
# 2023-02-01 14:48:45           https://twitter.com/RTikia/status/1620796300815106049
# 2023-02-01 14:48:54           https://twitter.com/RTikia/status/1620796338094108672
# 2023-02-01 14:48:56         https://twitter.com/RanvierX/status/1620796347313197056
# 2023-02-01 14:49:20          https://twitter.com/tannngl/status/1620796445791223808
# 2023-02-01 14:49:25   https://twitter.com/UltraSonic2010/status/1620796466280435712
# 2023-02-01 14:49:26           https://twitter.com/RTikia/status/1620796469849767936
# 2023-02-01 14:49:34           https://twitter.com/RTikia/status/1620796504142389248
# 2023-02-01 14:49:53           https://twitter.com/RTikia/status/1620796586384306176
# 2023-02-01 14:50:08     https://twitter.com/bob_golliver/status/1620796647512100864
# 2023-02-01 14:50:35        https://twitter.com/ErinC8888/status/1620796760502456322
# 2023-02-01 14:50:38        https://twitter.com/c13409799/status/1620796775329337344
# 2023-02-01 14:50:40        https://twitter.com/ErinC8888/status/1620796781939523584
# 2023-02-01 14:50:51     https://twitter.com/RafaChessBcn/status/1620796830115319808
# 2023-02-01 14:51:04         https://twitter.com/seanmdav/status/1620796881571028992
# 2023-02-01 14:51:18     https://twitter.com/InfelizChino/status/1620796940819791872
# 2023-02-01 14:51:22     https://twitter.com/InfelizChino/status/1620796956594552832
# 2023-02-01 14:51:26   https://twitter.com/BakerSonPeekay/status/1620796976785915904
# 2023-02-01 14:51:28        https://twitter.com/br0wnmcse/status/1620796984226611201
# 2023-02-01 14:51:36  https://twitter.com/NighthawkBegins/status/1620797018577960961
# 2023-02-01 14:51:46         https://twitter.com/Wubbies7/status/1620797059224981507
# 2023-02-01 14:51:57      https://twitter.com/EdMatheson1/status/1620797106792595456
# 2023-02-01 14:51:59           https://twitter.com/RTikia/status/1620797113230852096
# 2023-02-01 14:52:25       https://twitter.com/lit_poster/status/1620797221460647936
# 2023-02-01 14:52:31         https://twitter.com/Garyb451/status/1620797245791821824
# 2023-02-01 14:52:57           https://twitter.com/pjmugs/status/1620797356886327296
# 2023-02-01 14:53:02           https://twitter.com/RTikia/status/1620797379447508992
# 2023-02-01 14:53:17       https://twitter.com/bryanatoms/status/1620797439769989120
# 2023-02-01 14:53:18   https://twitter.com/Larryszeminska/status/1620797446438924288
# 2023-02-01 14:53:29           https://twitter.com/RTikia/status/1620797492039389184
# 2023-02-01 14:53:41    https://twitter.com/KeepYrTurnsUp/status/1620797542085857280
# 2023-02-01 14:53:44        https://twitter.com/TheOxyCon/status/1620797553947328512
# 2023-02-01 14:53:52           https://twitter.com/b_clad/status/1620797586490953728
# 2023-02-01 14:53:58  https://twitter.com/miketow70210566/status/1620797612910858241
# 2023-02-01 14:54:15         https://twitter.com/ReallyKW/status/1620797682251079680
# 2023-02-01 14:54:30  https://twitter.com/Chiefs4thewin23/status/1620797747040505856
# 2023-02-01 14:54:35  https://twitter.com/jambiktoywood25/status/1620797769651998720
# 2023-02-01 14:54:41  https://twitter.com/jambiktoywood25/status/1620797792494178304
# 2023-02-01 14:54:47       https://twitter.com/grawallinc/status/1620797820050747393
# 2023-02-01 14:55:00     https://twitter.com/AmyBeyerlein/status/1620797873037389825
# 2023-02-01 14:55:00          https://twitter.com/enpeec2/status/1620797871556792321
# 2023-02-01 14:55:03   https://twitter.com/TrumpManRules1/status/1620797883653160960
# 2023-02-01 14:55:20        https://twitter.com/sustain05/status/1620797957456158720
# 2023-02-01 14:55:51  https://twitter.com/JamesRu35628271/status/1620798085571174400
# 2023-02-01 14:56:09        https://twitter.com/kats4cops/status/1620798163371294720
# 2023-02-01 14:56:59        https://twitter.com/UKBBNBlue/status/1620798373652746240
# 2023-02-01 14:57:03    https://twitter.com/whitneylee_AR/status/1620798389393960960
# 2023-02-01 14:57:25   https://twitter.com/WhitebreadHill/status/1620798481186291713
# 2023-02-01 14:57:28     https://twitter.com/scoutdrayton/status/1620798495648256000
# 2023-02-01 14:58:11     https://twitter.com/RajG30669985/status/1620798675109961728
# 2023-02-01 14:58:17      https://twitter.com/ANAALONSO10/status/1620798699856334848
# 2023-02-01 14:58:59    https://twitter.com/SteveUncooked/status/1620798876000358402
# 2023-02-01 14:59:09   https://twitter.com/anitalanderos3/status/1620798919134568448
# 2023-02-01 14:59:29        https://twitter.com/EdieKastl/status/1620799002370543616
# 2023-02-01 14:59:31         https://twitter.com/MSOswald/status/1620799010209660928
#
#                                    date  \
# date
# 2023-02-01 14:00:06 2023-02-01 14:00:06
# 2023-02-01 14:00:30 2023-02-01 14:00:30
# 2023-02-01 14:00:40 2023-02-01 14:00:40
# 2023-02-01 14:01:14 2023-02-01 14:01:14
# 2023-02-01 14:01:21 2023-02-01 14:01:21
# 2023-02-01 14:01:28 2023-02-01 14:01:28
# 2023-02-01 14:01:31 2023-02-01 14:01:31
# 2023-02-01 14:01:36 2023-02-01 14:01:36
# 2023-02-01 14:01:39 2023-02-01 14:01:39
# 2023-02-01 14:01:42 2023-02-01 14:01:42
# 2023-02-01 14:01:52 2023-02-01 14:01:52
# 2023-02-01 14:02:04 2023-02-01 14:02:04
# 2023-02-01 14:02:12 2023-02-01 14:02:12
# 2023-02-01 14:02:17 2023-02-01 14:02:17
# 2023-02-01 14:02:20 2023-02-01 14:02:20
# 2023-02-01 14:02:26 2023-02-01 14:02:26
# 2023-02-01 14:02:30 2023-02-01 14:02:30
# 2023-02-01 14:02:32 2023-02-01 14:02:32
# 2023-02-01 14:02:39 2023-02-01 14:02:39
# 2023-02-01 14:02:47 2023-02-01 14:02:47
# 2023-02-01 14:02:51 2023-02-01 14:02:51
# 2023-02-01 14:02:52 2023-02-01 14:02:52
# 2023-02-01 14:02:52 2023-02-01 14:02:52
# 2023-02-01 14:03:06 2023-02-01 14:03:06
# 2023-02-01 14:03:14 2023-02-01 14:03:14
# 2023-02-01 14:03:17 2023-02-01 14:03:17
# 2023-02-01 14:03:24 2023-02-01 14:03:24
# 2023-02-01 14:03:26 2023-02-01 14:03:26
# 2023-02-01 14:03:31 2023-02-01 14:03:31
# 2023-02-01 14:03:32 2023-02-01 14:03:32
# 2023-02-01 14:03:32 2023-02-01 14:03:32
# 2023-02-01 14:03:37 2023-02-01 14:03:37
# 2023-02-01 14:03:39 2023-02-01 14:03:39
# 2023-02-01 14:03:39 2023-02-01 14:03:39
# 2023-02-01 14:03:43 2023-02-01 14:03:43
# 2023-02-01 14:03:43 2023-02-01 14:03:43
# 2023-02-01 14:03:50 2023-02-01 14:03:50
# 2023-02-01 14:03:59 2023-02-01 14:03:59
# 2023-02-01 14:04:13 2023-02-01 14:04:13
# 2023-02-01 14:04:15 2023-02-01 14:04:15
# 2023-02-01 14:04:25 2023-02-01 14:04:25
# 2023-02-01 14:04:30 2023-02-01 14:04:30
# 2023-02-01 14:04:30 2023-02-01 14:04:30
# 2023-02-01 14:04:50 2023-02-01 14:04:50
# 2023-02-01 14:04:54 2023-02-01 14:04:54
# 2023-02-01 14:04:58 2023-02-01 14:04:58
# 2023-02-01 14:05:00 2023-02-01 14:05:00
# 2023-02-01 14:05:05 2023-02-01 14:05:05
# 2023-02-01 14:05:21 2023-02-01 14:05:21
# 2023-02-01 14:05:26 2023-02-01 14:05:26
# 2023-02-01 14:05:37 2023-02-01 14:05:37
# 2023-02-01 14:05:58 2023-02-01 14:05:58
# 2023-02-01 14:06:10 2023-02-01 14:06:10
# 2023-02-01 14:06:14 2023-02-01 14:06:14
# 2023-02-01 14:06:15 2023-02-01 14:06:15
# 2023-02-01 14:06:18 2023-02-01 14:06:18
# 2023-02-01 14:06:19 2023-02-01 14:06:19
# 2023-02-01 14:06:34 2023-02-01 14:06:34
# 2023-02-01 14:06:37 2023-02-01 14:06:37
# 2023-02-01 14:06:37 2023-02-01 14:06:37
# 2023-02-01 14:06:39 2023-02-01 14:06:39
# 2023-02-01 14:06:42 2023-02-01 14:06:42
# 2023-02-01 14:06:50 2023-02-01 14:06:50
# 2023-02-01 14:06:56 2023-02-01 14:06:56
# 2023-02-01 14:07:06 2023-02-01 14:07:06
# 2023-02-01 14:07:23 2023-02-01 14:07:23
# 2023-02-01 14:07:25 2023-02-01 14:07:25
# 2023-02-01 14:07:35 2023-02-01 14:07:35
# 2023-02-01 14:07:52 2023-02-01 14:07:52
# 2023-02-01 14:08:03 2023-02-01 14:08:03
# 2023-02-01 14:08:06 2023-02-01 14:08:06
# 2023-02-01 14:08:46 2023-02-01 14:08:46
# 2023-02-01 14:08:46 2023-02-01 14:08:46
# 2023-02-01 14:09:08 2023-02-01 14:09:08
# 2023-02-01 14:09:13 2023-02-01 14:09:13
# 2023-02-01 14:09:14 2023-02-01 14:09:14
# 2023-02-01 14:09:18 2023-02-01 14:09:18
# 2023-02-01 14:09:41 2023-02-01 14:09:41
# 2023-02-01 14:09:41 2023-02-01 14:09:41
# 2023-02-01 14:09:42 2023-02-01 14:09:42
# 2023-02-01 14:09:48 2023-02-01 14:09:48
# 2023-02-01 14:10:08 2023-02-01 14:10:08
# 2023-02-01 14:10:18 2023-02-01 14:10:18
# 2023-02-01 14:10:33 2023-02-01 14:10:33
# 2023-02-01 14:10:37 2023-02-01 14:10:37
# 2023-02-01 14:10:48 2023-02-01 14:10:48
# 2023-02-01 14:10:50 2023-02-01 14:10:50
# 2023-02-01 14:10:56 2023-02-01 14:10:56
# 2023-02-01 14:10:57 2023-02-01 14:10:57
# 2023-02-01 14:10:57 2023-02-01 14:10:57
# 2023-02-01 14:11:02 2023-02-01 14:11:02
# 2023-02-01 14:11:15 2023-02-01 14:11:15
# 2023-02-01 14:11:22 2023-02-01 14:11:22
# 2023-02-01 14:11:23 2023-02-01 14:11:23
# 2023-02-01 14:11:28 2023-02-01 14:11:28
# 2023-02-01 14:11:34 2023-02-01 14:11:34
# 2023-02-01 14:12:06 2023-02-01 14:12:06
# 2023-02-01 14:12:46 2023-02-01 14:12:46
# 2023-02-01 14:13:12 2023-02-01 14:13:12
# 2023-02-01 14:13:15 2023-02-01 14:13:15
# 2023-02-01 14:13:54 2023-02-01 14:13:54
# 2023-02-01 14:13:58 2023-02-01 14:13:58
# 2023-02-01 14:14:07 2023-02-01 14:14:07
# 2023-02-01 14:14:24 2023-02-01 14:14:24
# 2023-02-01 14:14:24 2023-02-01 14:14:24
# 2023-02-01 14:14:27 2023-02-01 14:14:27
# 2023-02-01 14:14:31 2023-02-01 14:14:31
# 2023-02-01 14:14:31 2023-02-01 14:14:31
# 2023-02-01 14:14:32 2023-02-01 14:14:32
# 2023-02-01 14:14:42 2023-02-01 14:14:42
# 2023-02-01 14:14:43 2023-02-01 14:14:43
# 2023-02-01 14:14:48 2023-02-01 14:14:48
# 2023-02-01 14:14:48 2023-02-01 14:14:48
# 2023-02-01 14:14:56 2023-02-01 14:14:56
# 2023-02-01 14:15:00 2023-02-01 14:15:00
# 2023-02-01 14:15:06 2023-02-01 14:15:06
# 2023-02-01 14:15:10 2023-02-01 14:15:10
# 2023-02-01 14:15:19 2023-02-01 14:15:19
# 2023-02-01 14:15:19 2023-02-01 14:15:19
# 2023-02-01 14:16:16 2023-02-01 14:16:16
# 2023-02-01 14:17:15 2023-02-01 14:17:15
# 2023-02-01 14:17:16 2023-02-01 14:17:16
# 2023-02-01 14:17:17 2023-02-01 14:17:17
# 2023-02-01 14:17:22 2023-02-01 14:17:22
# 2023-02-01 14:17:24 2023-02-01 14:17:24
# 2023-02-01 14:17:29 2023-02-01 14:17:29
# 2023-02-01 14:17:32 2023-02-01 14:17:32
# 2023-02-01 14:17:44 2023-02-01 14:17:44
# 2023-02-01 14:17:50 2023-02-01 14:17:50
# 2023-02-01 14:18:03 2023-02-01 14:18:03
# 2023-02-01 14:18:08 2023-02-01 14:18:08
# 2023-02-01 14:18:13 2023-02-01 14:18:13
# 2023-02-01 14:18:36 2023-02-01 14:18:36
# 2023-02-01 14:18:43 2023-02-01 14:18:43
# 2023-02-01 14:19:00 2023-02-01 14:19:00
# 2023-02-01 14:19:18 2023-02-01 14:19:18
# 2023-02-01 14:19:55 2023-02-01 14:19:55
# 2023-02-01 14:20:07 2023-02-01 14:20:07
# 2023-02-01 14:20:12 2023-02-01 14:20:12
# 2023-02-01 14:20:27 2023-02-01 14:20:27
# 2023-02-01 14:20:31 2023-02-01 14:20:31
# 2023-02-01 14:21:01 2023-02-01 14:21:01
# 2023-02-01 14:21:05 2023-02-01 14:21:05
# 2023-02-01 14:21:18 2023-02-01 14:21:18
# 2023-02-01 14:21:26 2023-02-01 14:21:26
# 2023-02-01 14:21:39 2023-02-01 14:21:39
# 2023-02-01 14:21:50 2023-02-01 14:21:50
# 2023-02-01 14:22:15 2023-02-01 14:22:15
# 2023-02-01 14:22:25 2023-02-01 14:22:25
# 2023-02-01 14:22:32 2023-02-01 14:22:32
# 2023-02-01 14:22:37 2023-02-01 14:22:37
# 2023-02-01 14:22:50 2023-02-01 14:22:50
# 2023-02-01 14:22:50 2023-02-01 14:22:50
# 2023-02-01 14:22:59 2023-02-01 14:22:59
# 2023-02-01 14:23:16 2023-02-01 14:23:16
# 2023-02-01 14:23:18 2023-02-01 14:23:18
# 2023-02-01 14:23:47 2023-02-01 14:23:47
# 2023-02-01 14:24:06 2023-02-01 14:24:06
# 2023-02-01 14:24:07 2023-02-01 14:24:07
# 2023-02-01 14:24:14 2023-02-01 14:24:14
# 2023-02-01 14:24:29 2023-02-01 14:24:29
# 2023-02-01 14:24:32 2023-02-01 14:24:32
# 2023-02-01 14:25:47 2023-02-01 14:25:47
# 2023-02-01 14:25:50 2023-02-01 14:25:50
# 2023-02-01 14:25:54 2023-02-01 14:25:54
# 2023-02-01 14:25:56 2023-02-01 14:25:56
# 2023-02-01 14:26:03 2023-02-01 14:26:03
# 2023-02-01 14:26:09 2023-02-01 14:26:09
# 2023-02-01 14:26:11 2023-02-01 14:26:11
# 2023-02-01 14:26:39 2023-02-01 14:26:39
# 2023-02-01 14:27:24 2023-02-01 14:27:24
# 2023-02-01 14:27:59 2023-02-01 14:27:59
# 2023-02-01 14:28:19 2023-02-01 14:28:19
# 2023-02-01 14:28:30 2023-02-01 14:28:30
# 2023-02-01 14:29:10 2023-02-01 14:29:10
# 2023-02-01 14:29:19 2023-02-01 14:29:19
# 2023-02-01 14:29:20 2023-02-01 14:29:20
# 2023-02-01 14:29:26 2023-02-01 14:29:26
# 2023-02-01 14:29:30 2023-02-01 14:29:30
# 2023-02-01 14:30:40 2023-02-01 14:30:40
# 2023-02-01 14:30:40 2023-02-01 14:30:40
# 2023-02-01 14:31:04 2023-02-01 14:31:04
# 2023-02-01 14:31:18 2023-02-01 14:31:18
# 2023-02-01 14:31:23 2023-02-01 14:31:23
# 2023-02-01 14:31:24 2023-02-01 14:31:24
# 2023-02-01 14:32:00 2023-02-01 14:32:00
# 2023-02-01 14:32:03 2023-02-01 14:32:03
# 2023-02-01 14:32:29 2023-02-01 14:32:29
# 2023-02-01 14:32:38 2023-02-01 14:32:38
# 2023-02-01 14:33:03 2023-02-01 14:33:03
# 2023-02-01 14:33:21 2023-02-01 14:33:21
# 2023-02-01 14:33:28 2023-02-01 14:33:28
# 2023-02-01 14:33:31 2023-02-01 14:33:31
# 2023-02-01 14:34:17 2023-02-01 14:34:17
# 2023-02-01 14:34:17 2023-02-01 14:34:17
# 2023-02-01 14:34:20 2023-02-01 14:34:20
# 2023-02-01 14:34:28 2023-02-01 14:34:28
# 2023-02-01 14:34:33 2023-02-01 14:34:33
# 2023-02-01 14:34:34 2023-02-01 14:34:34
# 2023-02-01 14:34:41 2023-02-01 14:34:41
# 2023-02-01 14:34:42 2023-02-01 14:34:42
# 2023-02-01 14:34:43 2023-02-01 14:34:43
# 2023-02-01 14:34:45 2023-02-01 14:34:45
# 2023-02-01 14:34:47 2023-02-01 14:34:47
# 2023-02-01 14:34:52 2023-02-01 14:34:52
# 2023-02-01 14:34:53 2023-02-01 14:34:53
# 2023-02-01 14:34:53 2023-02-01 14:34:53
# 2023-02-01 14:34:55 2023-02-01 14:34:55
# 2023-02-01 14:35:03 2023-02-01 14:35:03
# 2023-02-01 14:35:19 2023-02-01 14:35:19
# 2023-02-01 14:35:24 2023-02-01 14:35:24
# 2023-02-01 14:35:38 2023-02-01 14:35:38
# 2023-02-01 14:35:39 2023-02-01 14:35:39
# 2023-02-01 14:36:18 2023-02-01 14:36:18
# 2023-02-01 14:36:20 2023-02-01 14:36:20
# 2023-02-01 14:36:26 2023-02-01 14:36:26
# 2023-02-01 14:36:27 2023-02-01 14:36:27
# 2023-02-01 14:36:28 2023-02-01 14:36:28
# 2023-02-01 14:37:11 2023-02-01 14:37:11
# 2023-02-01 14:37:37 2023-02-01 14:37:37
# 2023-02-01 14:37:40 2023-02-01 14:37:40
# 2023-02-01 14:38:03 2023-02-01 14:38:03
# 2023-02-01 14:38:15 2023-02-01 14:38:15
# 2023-02-01 14:38:29 2023-02-01 14:38:29
# 2023-02-01 14:38:29 2023-02-01 14:38:29
# 2023-02-01 14:38:32 2023-02-01 14:38:32
# 2023-02-01 14:38:37 2023-02-01 14:38:37
# 2023-02-01 14:39:00 2023-02-01 14:39:00
# 2023-02-01 14:39:00 2023-02-01 14:39:00
# 2023-02-01 14:39:07 2023-02-01 14:39:07
# 2023-02-01 14:39:10 2023-02-01 14:39:10
# 2023-02-01 14:39:29 2023-02-01 14:39:29
# 2023-02-01 14:39:29 2023-02-01 14:39:29
# 2023-02-01 14:39:35 2023-02-01 14:39:35
# 2023-02-01 14:39:37 2023-02-01 14:39:37
# 2023-02-01 14:39:44 2023-02-01 14:39:44
# 2023-02-01 14:40:18 2023-02-01 14:40:18
# 2023-02-01 14:40:25 2023-02-01 14:40:25
# 2023-02-01 14:40:37 2023-02-01 14:40:37
# 2023-02-01 14:40:38 2023-02-01 14:40:38
# 2023-02-01 14:40:40 2023-02-01 14:40:40
# 2023-02-01 14:40:47 2023-02-01 14:40:47
# 2023-02-01 14:40:57 2023-02-01 14:40:57
# 2023-02-01 14:41:06 2023-02-01 14:41:06
# 2023-02-01 14:41:11 2023-02-01 14:41:11
# 2023-02-01 14:41:37 2023-02-01 14:41:37
# 2023-02-01 14:41:59 2023-02-01 14:41:59
# 2023-02-01 14:42:00 2023-02-01 14:42:00
# 2023-02-01 14:42:08 2023-02-01 14:42:08
# 2023-02-01 14:42:37 2023-02-01 14:42:37
# 2023-02-01 14:42:55 2023-02-01 14:42:55
# 2023-02-01 14:42:55 2023-02-01 14:42:55
# 2023-02-01 14:43:09 2023-02-01 14:43:09
# 2023-02-01 14:43:29 2023-02-01 14:43:29
# 2023-02-01 14:43:38 2023-02-01 14:43:38
# 2023-02-01 14:43:47 2023-02-01 14:43:47
# 2023-02-01 14:43:53 2023-02-01 14:43:53
# 2023-02-01 14:44:34 2023-02-01 14:44:34
# 2023-02-01 14:44:42 2023-02-01 14:44:42
# 2023-02-01 14:45:09 2023-02-01 14:45:09
# 2023-02-01 14:46:12 2023-02-01 14:46:12
# 2023-02-01 14:46:53 2023-02-01 14:46:53
# 2023-02-01 14:47:05 2023-02-01 14:47:05
# 2023-02-01 14:47:14 2023-02-01 14:47:14
# 2023-02-01 14:47:54 2023-02-01 14:47:54
# 2023-02-01 14:47:58 2023-02-01 14:47:58
# 2023-02-01 14:48:32 2023-02-01 14:48:32
# 2023-02-01 14:48:37 2023-02-01 14:48:37
# 2023-02-01 14:48:45 2023-02-01 14:48:45
# 2023-02-01 14:48:45 2023-02-01 14:48:45
# 2023-02-01 14:48:54 2023-02-01 14:48:54
# 2023-02-01 14:48:56 2023-02-01 14:48:56
# 2023-02-01 14:49:20 2023-02-01 14:49:20
# 2023-02-01 14:49:25 2023-02-01 14:49:25
# 2023-02-01 14:49:26 2023-02-01 14:49:26
# 2023-02-01 14:49:34 2023-02-01 14:49:34
# 2023-02-01 14:49:53 2023-02-01 14:49:53
# 2023-02-01 14:50:08 2023-02-01 14:50:08
# 2023-02-01 14:50:35 2023-02-01 14:50:35
# 2023-02-01 14:50:38 2023-02-01 14:50:38
# 2023-02-01 14:50:40 2023-02-01 14:50:40
# 2023-02-01 14:50:51 2023-02-01 14:50:51
# 2023-02-01 14:51:04 2023-02-01 14:51:04
# 2023-02-01 14:51:18 2023-02-01 14:51:18
# 2023-02-01 14:51:22 2023-02-01 14:51:22
# 2023-02-01 14:51:26 2023-02-01 14:51:26
# 2023-02-01 14:51:28 2023-02-01 14:51:28
# 2023-02-01 14:51:36 2023-02-01 14:51:36
# 2023-02-01 14:51:46 2023-02-01 14:51:46
# 2023-02-01 14:51:57 2023-02-01 14:51:57
# 2023-02-01 14:51:59 2023-02-01 14:51:59
# 2023-02-01 14:52:25 2023-02-01 14:52:25
# 2023-02-01 14:52:31 2023-02-01 14:52:31
# 2023-02-01 14:52:57 2023-02-01 14:52:57
# 2023-02-01 14:53:02 2023-02-01 14:53:02
# 2023-02-01 14:53:17 2023-02-01 14:53:17
# 2023-02-01 14:53:18 2023-02-01 14:53:18
# 2023-02-01 14:53:29 2023-02-01 14:53:29
# 2023-02-01 14:53:41 2023-02-01 14:53:41
# 2023-02-01 14:53:44 2023-02-01 14:53:44
# 2023-02-01 14:53:52 2023-02-01 14:53:52
# 2023-02-01 14:53:58 2023-02-01 14:53:58
# 2023-02-01 14:54:15 2023-02-01 14:54:15
# 2023-02-01 14:54:30 2023-02-01 14:54:30
# 2023-02-01 14:54:35 2023-02-01 14:54:35
# 2023-02-01 14:54:41 2023-02-01 14:54:41
# 2023-02-01 14:54:47 2023-02-01 14:54:47
# 2023-02-01 14:55:00 2023-02-01 14:55:00
# 2023-02-01 14:55:00 2023-02-01 14:55:00
# 2023-02-01 14:55:03 2023-02-01 14:55:03
# 2023-02-01 14:55:20 2023-02-01 14:55:20
# 2023-02-01 14:55:51 2023-02-01 14:55:51
# 2023-02-01 14:56:09 2023-02-01 14:56:09
# 2023-02-01 14:56:59 2023-02-01 14:56:59
# 2023-02-01 14:57:03 2023-02-01 14:57:03
# 2023-02-01 14:57:25 2023-02-01 14:57:25
# 2023-02-01 14:57:28 2023-02-01 14:57:28
# 2023-02-01 14:58:11 2023-02-01 14:58:11
# 2023-02-01 14:58:17 2023-02-01 14:58:17
# 2023-02-01 14:58:59 2023-02-01 14:58:59
# 2023-02-01 14:59:09 2023-02-01 14:59:09
# 2023-02-01 14:59:29 2023-02-01 14:59:29
# 2023-02-01 14:59:31 2023-02-01 14:59:31
#
#                                                                                                                                                                                                                                                                                                                                                                                                                      renderedContent  \
# date
# 2023-02-01 14:00:06                                                                                                                                                                                                                                                                                                        Twitter, Media, And Democrats Are All Guilty In The Hamilton 68 Scandal thefederalist.com/2023/02/01/twi…
# 2023-02-01 14:00:30                                                                                                                                                                                                                                                                                                     Twitter, Media, And Democrats Are All Guilty In The Hamilton 68 Scandal\n\nthefederalist.com/2023/02/01/twi…
# 2023-02-01 14:00:40                                                                                                                                                                                                                                                                                       RT @MZHemingway: Twitter, Media, And Democrats Are All Guilty In The Hamilton 68 Scandal thefederalist.com/2023/02/01/twi…
# 2023-02-01 14:01:14                                                                                                                                                                                                                                                                                       RT @MZHemingway: Twitter, Media, And Democrats Are All Guilty In The Hamilton 68 Scandal thefederalist.com/2023/02/01/twi…
# 2023-02-01 14:01:21                                                                                                                                                                                                                                                                                         RT @FDRLST: Twitter, Media, And Democrats Are All Guilty In The Hamilton 68 Scandal\n\nthefederalist.com/2023/02/01/twi…
# 2023-02-01 14:01:28                                                                                                                                                                                                                                                                                       RT @MZHemingway: Twitter, Media, And Democrats Are All Guilty In The Hamilton 68 Scandal thefederalist.com/2023/02/01/twi…
# 2023-02-01 14:01:31                                                                                                                                                                                                                                                                                       RT @MZHemingway: Twitter, Media, And Democrats Are All Guilty In The Hamilton 68 Scandal thefederalist.com/2023/02/01/twi…
# 2023-02-01 14:01:36                                                                                                                                                                                                                                                                     RT @HelenaVillarRT: 💻Una nueva entrega de los archivos de Twitter ha revelado que Hamilton 68, una de las principales herramientas utilizad…
# 2023-02-01 14:01:39                                                                                                                                                                                                                                                                                       RT @MZHemingway: Twitter, Media, And Democrats Are All Guilty In The Hamilton 68 Scandal thefederalist.com/2023/02/01/twi…
# 2023-02-01 14:01:42                                                                                                                                                                                                                                                                                       RT @MZHemingway: Twitter, Media, And Democrats Are All Guilty In The Hamilton 68 Scandal thefederalist.com/2023/02/01/twi…
# 2023-02-01 14:01:52                                                                                                                                                                                                                                                                                         RT @FDRLST: Twitter, Media, And Democrats Are All Guilty In The Hamilton 68 Scandal\n\nthefederalist.com/2023/02/01/twi…
# ...
# 2023-02-01 14:51:57               --                    --        --    --
# 2023-02-01 14:51:59               --                    --        --    --
# 2023-02-01 14:52:25               --                    --        --    --
# 2023-02-01 14:52:31               --                    --        --    --
# 2023-02-01 14:52:57               --                    --        --    --
# 2023-02-01 14:53:02               --                    --        --    --
# 2023-02-01 14:53:17               --                    --        --    --
# 2023-02-01 14:53:18               --                    --        --    --
# 2023-02-01 14:53:29               --                    --        --    --
# 2023-02-01 14:53:41               --                    --        --    --
# 2023-02-01 14:53:44               --                    --        --    --
# 2023-02-01 14:53:52               --                    --        --    --
# 2023-02-01 14:53:58               --                    --        --    --
# 2023-02-01 14:54:15               --                    --        --    --
# 2023-02-01 14:54:30               --                    --        --    --
# 2023-02-01 14:54:35               --                    --        --    --
# 2023-02-01 14:54:41               --                    --        --    --
# 2023-02-01 14:54:47               --                    --        --    --
# 2023-02-01 14:55:00               --                    --        --    --
# 2023-02-01 14:55:00               --                    --        --    --
# 2023-02-01 14:55:03               --                    --        --    --
# 2023-02-01 14:55:20               --                    --        --    --
# 2023-02-01 14:55:51               --                    --        --    --
# 2023-02-01 14:56:09               --                    --        --    --
# 2023-02-01 14:56:59               --                    --        --    --
# 2023-02-01 14:57:03               --                    --        --    --
# 2023-02-01 14:57:25               --                    --        --    --
# 2023-02-01 14:57:28               --                    --        --    --
# 2023-02-01 14:58:11               --                    --        --    --
# 2023-02-01 14:58:17               --                    --        --    --
# 2023-02-01 14:58:59               --                    --        --    --
# 2023-02-01 14:59:09               --                    --        --    --
# 2023-02-01 14:59:29               --                    --        --    --
# 2023-02-01 14:59:31               --                    --        --    --
#
#                      total_engagements
# date
# 2023-02-01 14:00:06               1519
# 2023-02-01 14:00:30                133
# 2023-02-01 14:00:40                367
# 2023-02-01 14:01:14                367
# 2023-02-01 14:01:21                 32
# 2023-02-01 14:01:28                367
# 2023-02-01 14:01:31                367
# 2023-02-01 14:01:36                298
# 2023-02-01 14:01:39                367
# 2023-02-01 14:01:42                367
# 2023-02-01 14:01:52                 32
# 2023-02-01 14:02:04                 32
# 2023-02-01 14:02:12                 32
# 2023-02-01 14:02:17                367
# 2023-02-01 14:02:20                  0
# 2023-02-01 14:02:26                367
# 2023-02-01 14:02:30                102
# 2023-02-01 14:02:32                367
# 2023-02-01 14:02:39                367
# 2023-02-01 14:02:47                367
# 2023-02-01 14:02:51                367
# 2023-02-01 14:02:52                367
# 2023-02-01 14:02:52                  1
# 2023-02-01 14:03:06                367
# 2023-02-01 14:03:14                367
# 2023-02-01 14:03:17                367
# 2023-02-01 14:03:24                367
# 2023-02-01 14:03:26                 24
# 2023-02-01 14:03:31                367
# 2023-02-01 14:03:32                367
# 2023-02-01 14:03:32                367
# 2023-02-01 14:03:37                367
# 2023-02-01 14:03:39                367
# 2023-02-01 14:03:39                 24
# 2023-02-01 14:03:43                367
# 2023-02-01 14:03:43                367
# 2023-02-01 14:03:50                367
# 2023-02-01 14:03:59                367
# 2023-02-01 14:04:13                 32
# 2023-02-01 14:04:15                367
# 2023-02-01 14:04:25                 32
# 2023-02-01 14:04:30                352
# 2023-02-01 14:04:30                367
# 2023-02-01 14:04:50                367
# 2023-02-01 14:04:54                367
# 2023-02-01 14:04:58               3144
# 2023-02-01 14:05:00                 32
# 2023-02-01 14:05:05                 24
# 2023-02-01 14:05:21                367
# 2023-02-01 14:05:26                 32
# 2023-02-01 14:05:37                367
# 2023-02-01 14:05:58                  0
# 2023-02-01 14:06:10                791
# 2023-02-01 14:06:14                 37
# 2023-02-01 14:06:15                367
# 2023-02-01 14:06:18                 32
# 2023-02-01 14:06:19                394
# 2023-02-01 14:06:34                 32
# 2023-02-01 14:06:37                367
# 2023-02-01 14:06:37                  0
# 2023-02-01 14:06:39                298
# 2023-02-01 14:06:42                367
# 2023-02-01 14:06:50                367
# 2023-02-01 14:06:56                  0
# 2023-02-01 14:07:06                367
# 2023-02-01 14:07:23                 24
# 2023-02-01 14:07:25                352
# 2023-02-01 14:07:35               5405
# 2023-02-01 14:07:52                367
# 2023-02-01 14:08:03                 24
# 2023-02-01 14:08:06                367
# 2023-02-01 14:08:46                367
# 2023-02-01 14:08:46                352
# 2023-02-01 14:09:08                 24
# 2023-02-01 14:09:13                367
# 2023-02-01 14:09:14               1790
# 2023-02-01 14:09:18                 24
# 2023-02-01 14:09:41                 32
# 2023-02-01 14:09:41                367
# 2023-02-01 14:09:42                367
# 2023-02-01 14:09:48                367
# 2023-02-01 14:10:08                 32
# 2023-02-01 14:10:18                367
# 2023-02-01 14:10:33                367
# 2023-02-01 14:10:37                367
# 2023-02-01 14:10:48                367
# 2023-02-01 14:10:50                367
# 2023-02-01 14:10:56               9850
# 2023-02-01 14:10:57                367
# 2023-02-01 14:10:57                  0
# 2023-02-01 14:11:02                367
# 2023-02-01 14:11:15               6496
# 2023-02-01 14:11:22                 32
# 2023-02-01 14:11:23                367
# 2023-02-01 14:11:28                 24
# 2023-02-01 14:11:34                367
# 2023-02-01 14:12:06               9850
# 2023-02-01 14:12:46                367
# 2023-02-01 14:13:12                  0
# 2023-02-01 14:13:15                 32
# 2023-02-01 14:13:54                 32
# 2023-02-01 14:13:58                367
# 2023-02-01 14:14:07                175
# 2023-02-01 14:14:24                367
# 2023-02-01 14:14:24                367
# 2023-02-01 14:14:27                367
# 2023-02-01 14:14:31                367
# 2023-02-01 14:14:31                367
# 2023-02-01 14:14:32                367
# 2023-02-01 14:14:42               9850
# 2023-02-01 14:14:43                367
# 2023-02-01 14:14:48                  0
# 2023-02-01 14:14:48               2690
# 2023-02-01 14:14:56               3588
# 2023-02-01 14:15:00                367
# 2023-02-01 14:15:06                367
# 2023-02-01 14:15:10                  0
# 2023-02-01 14:15:19                 26
# 2023-02-01 14:15:19               2084
# 2023-02-01 14:16:16                 24
# 2023-02-01 14:17:15               2979
# 2023-02-01 14:17:16                367
# 2023-02-01 14:17:17               2104
# 2023-02-01 14:17:22                367
# 2023-02-01 14:17:24                367
# 2023-02-01 14:17:29                 24
# 2023-02-01 14:17:32                367
# 2023-02-01 14:17:44                352
# 2023-02-01 14:17:50                352
# 2023-02-01 14:18:03                367
# 2023-02-01 14:18:08               1216
# 2023-02-01 14:18:13                298
# 2023-02-01 14:18:36                352
# 2023-02-01 14:18:43                 45
# 2023-02-01 14:19:00               1826
# 2023-02-01 14:19:18                367
# 2023-02-01 14:19:55                  2
# 2023-02-01 14:20:07                367
# 2023-02-01 14:20:12                  0
# 2023-02-01 14:20:27                367
# 2023-02-01 14:20:31                367
# 2023-02-01 14:21:01                367
# 2023-02-01 14:21:05                367
# 2023-02-01 14:21:18                367
# 2023-02-01 14:21:26                352
# 2023-02-01 14:21:39                367
# 2023-02-01 14:21:50                367
# 2023-02-01 14:22:15                  0
# 2023-02-01 14:22:25                 32
# 2023-02-01 14:22:32                 32
# 2023-02-01 14:22:37                352
# 2023-02-01 14:22:50                367
# 2023-02-01 14:22:50                367
# 2023-02-01 14:22:59                  0
# 2023-02-01 14:23:16               6496
# 2023-02-01 14:23:18                367
# 2023-02-01 14:23:47                367
# 2023-02-01 14:24:06               5405
# 2023-02-01 14:24:07                367
# 2023-02-01 14:24:14                367
# 2023-02-01 14:24:29                 32
# 2023-02-01 14:24:32                367
# 2023-02-01 14:25:47                 32
# 2023-02-01 14:25:50                367
# 2023-02-01 14:25:54                352
# 2023-02-01 14:25:56                  1
# 2023-02-01 14:26:03                367
# 2023-02-01 14:26:09                  0
# 2023-02-01 14:26:11                352
# 2023-02-01 14:26:39                 43
# 2023-02-01 14:27:24                367
# 2023-02-01 14:27:59                367
# 2023-02-01 14:28:19                352
# 2023-02-01 14:28:30                367
# 2023-02-01 14:29:10                367
# 2023-02-01 14:29:19                 45
# 2023-02-01 14:29:20                367
# 2023-02-01 14:29:26               5405
# 2023-02-01 14:29:30                367
# 2023-02-01 14:30:40                367
# 2023-02-01 14:30:40               9850
# 2023-02-01 14:31:04                367
# 2023-02-01 14:31:18                367
# 2023-02-01 14:31:23                367
# 2023-02-01 14:31:24                367
# 2023-02-01 14:32:00                 32
# 2023-02-01 14:32:03                394
# 2023-02-01 14:32:29               9850
# 2023-02-01 14:32:38                367
# 2023-02-01 14:33:03               6496
# 2023-02-01 14:33:21                 43
# 2023-02-01 14:33:28                  6
# 2023-02-01 14:33:31                791
# 2023-02-01 14:34:17                317
# 2023-02-01 14:34:17               6496
# 2023-02-01 14:34:20                367
# 2023-02-01 14:34:28                 85
# 2023-02-01 14:34:33                 85
# 2023-02-01 14:34:34                367
# 2023-02-01 14:34:41                 85
# 2023-02-01 14:34:42                367
# 2023-02-01 14:34:43                 85
# 2023-02-01 14:34:45                 85
# 2023-02-01 14:34:47                 85
# 2023-02-01 14:34:52                 85
# 2023-02-01 14:34:53                 85
# 2023-02-01 14:34:53                367
# 2023-02-01 14:34:55                 85
# 2023-02-01 14:35:03                 85
# 2023-02-01 14:35:19                 85
# 2023-02-01 14:35:24                 85
# 2023-02-01 14:35:38                  0
# 2023-02-01 14:35:39                 85
# 2023-02-01 14:36:18                 85
# 2023-02-01 14:36:20                 85
# 2023-02-01 14:36:26               6496
# 2023-02-01 14:36:27                 85
# 2023-02-01 14:36:28                 85
# 2023-02-01 14:37:11                 85
# 2023-02-01 14:37:37                367
# 2023-02-01 14:37:40                  3
# 2023-02-01 14:38:03                 85
# 2023-02-01 14:38:15                 85
# 2023-02-01 14:38:29                394
# 2023-02-01 14:38:29                 85
# 2023-02-01 14:38:32                 85
# 2023-02-01 14:38:37                 85
# 2023-02-01 14:39:00                 85
# 2023-02-01 14:39:00                 85
# 2023-02-01 14:39:07                367
# 2023-02-01 14:39:10                352
# 2023-02-01 14:39:29                367
# 2023-02-01 14:39:29                 85
# 2023-02-01 14:39:35                 85
# 2023-02-01 14:39:37                 24
# 2023-02-01 14:39:44                367
# 2023-02-01 14:40:18                298
# 2023-02-01 14:40:25                  2
# 2023-02-01 14:40:37                 85
# 2023-02-01 14:40:38                367
# 2023-02-01 14:40:40                367
# 2023-02-01 14:40:47                 85
# 2023-02-01 14:40:57                 85
# 2023-02-01 14:41:06                 85
# 2023-02-01 14:41:11                367
# 2023-02-01 14:41:37                367
# 2023-02-01 14:41:59                367
# 2023-02-01 14:42:00               1528
# 2023-02-01 14:42:08               9850
# 2023-02-01 14:42:37                 85
# 2023-02-01 14:42:55                 85
# 2023-02-01 14:42:55                 85
# 2023-02-01 14:43:09               9850
# 2023-02-01 14:43:29                 85
# 2023-02-01 14:43:38                367
# 2023-02-01 14:43:47                367
# 2023-02-01 14:43:53                 85
# 2023-02-01 14:44:34                 85
# 2023-02-01 14:44:42                352
# 2023-02-01 14:45:09                367
# 2023-02-01 14:46:12                  1
# 2023-02-01 14:46:53                367
# 2023-02-01 14:47:05                352
# 2023-02-01 14:47:14                 85
# 2023-02-01 14:47:54                 85
# 2023-02-01 14:47:58                367
# 2023-02-01 14:48:32                 85
# 2023-02-01 14:48:37               2361
# 2023-02-01 14:48:45                 85
# 2023-02-01 14:48:45               2930
# 2023-02-01 14:48:54               2009
# 2023-02-01 14:48:56                 32
# 2023-02-01 14:49:20                 85
# 2023-02-01 14:49:25                394
# 2023-02-01 14:49:26               2690
# 2023-02-01 14:49:34               3588
# 2023-02-01 14:49:53               2084
# 2023-02-01 14:50:08                367
# 2023-02-01 14:50:35                 32
# 2023-02-01 14:50:38                 24
# 2023-02-01 14:50:40                367
# 2023-02-01 14:50:51                298
# 2023-02-01 14:51:04                367
# 2023-02-01 14:51:18                298
# 2023-02-01 14:51:22                 37
# 2023-02-01 14:51:26                367
# 2023-02-01 14:51:28                367
# 2023-02-01 14:51:36                  2
# 2023-02-01 14:51:46                367
# 2023-02-01 14:51:57                367
# 2023-02-01 14:51:59               2104
# 2023-02-01 14:52:25                367
# 2023-02-01 14:52:31                367
# 2023-02-01 14:52:57                 85
# 2023-02-01 14:53:02               1216
# 2023-02-01 14:53:17                352
# 2023-02-01 14:53:18                 85
# 2023-02-01 14:53:29               1442
# 2023-02-01 14:53:41                367
# 2023-02-01 14:53:44                367
# 2023-02-01 14:53:52                367
# 2023-02-01 14:53:58                367
# 2023-02-01 14:54:15                367
# 2023-02-01 14:54:30                367
# 2023-02-01 14:54:35                  9
# 2023-02-01 14:54:41                 43
# 2023-02-01 14:54:47                367
# 2023-02-01 14:55:00                367
# 2023-02-01 14:55:00                367
# 2023-02-01 14:55:03                367
# 2023-02-01 14:55:20                 24
# 2023-02-01 14:55:51                 85
# 2023-02-01 14:56:09               6496
# 2023-02-01 14:56:59                367
# 2023-02-01 14:57:03                367
# 2023-02-01 14:57:25                 85
# 2023-02-01 14:57:28                367
# 2023-02-01 14:58:11                367
# 2023-02-01 14:58:17                  2
# 2023-02-01 14:58:59                367
# 2023-02-01 14:59:09                352
# 2023-02-01 14:59:29                367
# 2023-02-01 14:59:31                 24

# %%
#visualize time series for occurrence of "Hamilton 68"
sns.set_style('whitegrid', {"grid.color": ".8", "grid.linestyle": ":", 'axes.edgecolor': 'Black', 
             'axes.grid': True})

f, axes = plt.subplots(figsize=(7,6))

resampled_df_ratio = concat_df.resample('d').count()
resampled_df_ratio['retweet_count'] = (concat_df[concat_df['retweetedUser']!='--']['url'].resample('d').count())
resampled_df_ratio['retweet_ratio'] = (concat_df[concat_df['retweetedUser']!='--']['url'].resample('d').count())/\
(concat_df['url'].resample('d').count())*100
resampled_df_ratio['date']=resampled_df_ratio.index
resampled_df_ratio = resampled_df_ratio[['date', 'url', 'retweet_count', 'retweet_ratio']]
resampled_df_ratio.rename(columns={'url': 'count'}, inplace=True)
resampled_df_ratio.fillna(value=0, inplace=True)

ax = sns.lineplot(data=resampled_df_ratio, x=resampled_df_ratio['date'], y=resampled_df_ratio['retweet_ratio'], color='DarkBlue')

ax.set(ylabel=None)
ax.set_xlabel('\nDate', fontsize=14, fontweight='bold', fontname="Plantagenet Cherokee")
ax.set_ylabel('Percentage\n', fontsize=14, fontweight='bold', fontname="Plantagenet Cherokee")
ax.tick_params(axis='y', labelsize=10)
ax.tick_params(axis='x', rotation=35)

ax.set_title('Daily Percentage of Retweets to Tweets\n', fontsize=22,\
         fontweight='bold', fontname="Plantagenet Cherokee", color='Red')

import matplotlib.dates as mdates
ax.xaxis.set_major_locator(mdates.DayLocator(interval=2))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b-%d-%Y'))

sns.despine()
plt.tight_layout()
# plt.show()

# f.savefig('/.../retweet_ratio.jpg', bbox_inches='tight')

# %%
#create lists for top links

links_list = []
links_count_list = []
links_counter = Counter()

for i in concat_df['links']:
    if i == '8.News' or i == '15.It':
        continue
    else:
        links_counter.update(i.split())
    
for i in links_counter:
    links_list.append(i)
    links_count_list.append(links_counter[i])

# %%
#produce nodes and edges tables for links

host_source_list = []
host_target_list = []
host_type_list = []

for i in range(len(concat_df)):
    if concat_df.iloc[i, :]['links'] != '--':
            if concat_df.iloc[i, :]['links'] != '8.News':
                    if concat_df.iloc[i, :]['links'] != '15.It':
                        host_source_list.append(concat_df.iloc[i, :]['user'])
                        host_target_list.append(concat_df.iloc[i, :]['links'])

host_id_list = list(set(host_source_list + host_target_list))

for i in host_id_list:
    if i in host_target_list:
        host_type_list.append('host')
    else:
        if i in host_source_list:
            host_type_list.append('user')

host_nodes_list_df = pd.DataFrame({'id': host_id_list,
                                  'label': host_id_list,
                                  'type': host_type_list})
host_edges_list_df = pd.DataFrame({'source': host_source_list,
                                     'target': host_target_list})

# host_nodes_list_df.to_csv('/...hamilton68_host_nodes.csv', sep=',', index=False)
# host_edges_list_df.to_csv('/...hamilton68_host_edges.csv', sep=',', index=False)

# %%
#visualize most popular links

f, axes = plt.subplots(figsize=(8,6))

links_top = 15

links_df = pd.DataFrame({'link': links_list,
                        'links_count': links_count_list}).sort_values('links_count', ascending=False)[1:links_top]

ax = sns.barplot(data=links_df, y='link', x='links_count', color='DarkBlue')

ax.set(ylabel=None)
ax.set_xlabel('\nNumber of Users', fontsize=14, fontweight='bold', fontname="Plantagenet Cherokee")
ax.tick_params(axis='y', labelsize=14)
ax.set_title('Top ' + str(links_top) + ' Domains by Links\n', fontsize=22, fontweight='bold', fontname="Plantagenet Cherokee", color='Red')

sns.despine()
plt.tight_layout()
# plt.show()

# f.savefig('/.../top_domains.jpg', bbox_inches='tight')
